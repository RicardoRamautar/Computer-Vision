# %% [markdown]
# # Step 2: Cloning and Building Darknet

# %%
# clone darknet repo
# !git clone https://github.com/AlexeyAB/darknet

# %%
# change makefile to have GPU and OPENCV enabled
# %cd darknet
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile
# !sed -i 's/CUDNN_HALF=0/CUDNN_HALF=1/' Makefile

# %%
# make darknet (builds darknet so that you can then use the darknet executable file to run or train object detectors)
# !make

# %% [markdown]
# # 3. Define helper function

# %%
# define helper functions
def imShow(path):
  import cv2
  import matplotlib.pyplot as plt
  # %matplotlib inline

  image = cv2.imread(path)
  height, width = image.shape[:2]
  resized_image = cv2.resize(image,(3*width, 3*height), interpolation = cv2.INTER_CUBIC)

  fig = plt.gcf()
  fig.set_size_inches(18, 10)
  plt.axis("off")
  plt.imshow(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
  plt.show()

# %% [markdown]
# # 4. Add files

# %%
# !cp -r /content/drive/MyDrive/Training\ Darknet\ YOLO/* /content/darknet
# !unzip -q /content/darknet/images.zip
# !mv /content/darknet/complete_dataset/ /content/darknet/images/
# %cd ..
# !unzip -q Training\ Darknet\ YOLO.zip
# !cp -r Training\ Darknet\ YOLO/* darknet
# !unzip -q darknet/images.zip
# !mv complete_dataset/ darknet/images/

# %% [markdown]
# # 5. Training YOLOv3 Tiny

# %%
# !./darknet detector train obj.data yolo3_tiny_v3.cfg yolov3_tiny_original.weights -clear -map

# %% [markdown]
# # 6. Testing YOLOv3 Tiny

# %%
# !./darknet detector map obj.data yolo3_tiny_v3.cfg yolo3_tiny_v3_best_largedataset.weights -iou_thresh 0.05
# !./darknet detector map obj.data yolo3_tiny_v3.cfg yolo3_tiny_v3_best_largedataset.weights -iou_thresh 0.10
# !./darknet detector map obj.data yolo3_tiny_v3.cfg yolo3_tiny_v3_best_largedataset.weights -iou_thresh 0.15
# !./darknet detector map obj.data yolo3_tiny_v3.cfg yolo3_tiny_v3_best_largedataset.weights -iou_thresh 0.20
# !./darknet detector map obj.data yolo3_tiny_v3.cfg yolo3_tiny_v3_best_largedataset.weights -iou_thresh 0.25
# !./darknet detector map obj.data yolo3_tiny_v3.cfg yolo3_tiny_v3_best_largedataset.weights -iou_thresh 0.30
# !./darknet detector map obj.data yolo3_tiny_v3.cfg yolo3_tiny_v3_best_largedataset.weights -iou_thresh 0.35
# !./darknet detector map obj.data yolo3_tiny_v3.cfg yolo3_tiny_v3_best_largedataset.weights -iou_thresh 0.40
# !./darknet detector map obj.data yolo3_tiny_v3.cfg yolo3_tiny_v3_best_largedataset.weights -iou_thresh 0.45
# !./darknet detector map obj.data yolo3_tiny_v3.cfg yolo3_tiny_v3_best_largedataset.weights -iou_thresh 0.50
# !./darknet detector map obj.data yolo3_tiny_v3.cfg yolo3_tiny_v3_best_largedataset.weights -iou_thresh 0.55
# !./darknet detector map obj.data yolo3_tiny_v3.cfg yolo3_tiny_v3_best_largedataset.weights -iou_thresh 0.60
# !./darknet detector map obj.data yolo3_tiny_v3.cfg yolo3_tiny_v3_best_largedataset.weights -iou_thresh 0.65
# !./darknet detector map obj.data yolo3_tiny_v3.cfg yolo3_tiny_v3_best_largedataset.weights -iou_thresh 0.70
# !./darknet detector map obj.data yolo3_tiny_v3.cfg yolo3_tiny_v3_best_largedataset.weights -iou_thresh 0.75
# !./darknet detector map obj.data yolo3_tiny_v3.cfg yolo3_tiny_v3_best_largedataset.weights -iou_thresh 0.80
# !./darknet detector map obj.data yolo3_tiny_v3.cfg yolo3_tiny_v3_best_largedataset.weights -iou_thresh 0.85
# !./darknet detector map obj.data yolo3_tiny_v3.cfg yolo3_tiny_v3_best_largedataset.weights -iou_thresh 0.90
# !./darknet detector map obj.data yolo3_tiny_v3.cfg yolo3_tiny_v3_best_largedataset.weights -iou_thresh 0.95

# %% [markdown]
# # 5. Training YOLOv3

# %%
# !./darknet detector train obj.data yolov3.cfg yolov3.weights -clear -map

# %% [markdown]
# # 6. Testing YOLOv3

# %%
# !./darknet detector map obj.data yolov3.cfg yolov3_best_largedataset.weights -iou_thresh 0.05
# !./darknet detector map obj.data yolov3.cfg yolov3_best_largedataset.weights -iou_thresh 0.10
# !./darknet detector map obj.data yolov3.cfg yolov3_best_largedataset.weights -iou_thresh 0.15
# !./darknet detector map obj.data yolov3.cfg yolov3_best_largedataset.weights -iou_thresh 0.20
# !./darknet detector map obj.data yolov3.cfg yolov3_best_largedataset.weights -iou_thresh 0.25
# !./darknet detector map obj.data yolov3.cfg yolov3_best_largedataset.weights -iou_thresh 0.30
# !./darknet detector map obj.data yolov3.cfg yolov3_best_largedataset.weights -iou_thresh 0.35
# !./darknet detector map obj.data yolov3.cfg yolov3_best_largedataset.weights -iou_thresh 0.40
# !./darknet detector map obj.data yolov3.cfg yolov3_best_largedataset.weights -iou_thresh 0.45
# !./darknet detector map obj.data yolov3.cfg yolov3_best_largedataset.weights -iou_thresh 0.50
# !./darknet detector map obj.data yolov3.cfg yolov3_best_largedataset.weights -iou_thresh 0.55
# !./darknet detector map obj.data yolov3.cfg yolov3_best_largedataset.weights -iou_thresh 0.60
# !./darknet detector map obj.data yolov3.cfg yolov3_best_largedataset.weights -iou_thresh 0.65
# !./darknet detector map obj.data yolov3.cfg yolov3_best_largedataset.weights -iou_thresh 0.70
# !./darknet detector map obj.data yolov3.cfg yolov3_best_largedataset.weights -iou_thresh 0.75
# !./darknet detector map obj.data yolov3.cfg yolov3_best_largedataset.weights -iou_thresh 0.80
# !./darknet detector map obj.data yolov3.cfg yolov3_best_largedataset.weights -iou_thresh 0.85
# !./darknet detector map obj.data yolov3.cfg yolov3_best_largedataset.weights -iou_thresh 0.90
# !./darknet detector map obj.data yolov3.cfg yolov3_best_largedataset.weights -iou_thresh 0.95
